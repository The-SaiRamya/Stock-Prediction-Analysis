# %% [markdown]
# # Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
df  = pd.read_csv("TATAMOTORS.csv")
df.plot()  # plots all columns against index
df.plot(kind='scatter',x='Turnover', y='%Deliverble') # scatter plot
df.plot(kind='density')  # estimate density function
df.plot(kind='hist')  # histogram
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.head()
# Out:
#          Date Symbol Series  Prev Close   Open    High    Low   Last   Close  \
# 0  2000-01-03  TELCO     EQ      201.60  207.4  217.25  207.4  217.0  216.75
# 1  2000-01-04  TELCO     EQ      216.75  217.0  219.00  206.0  211.9  208.20
# 2  2000-01-05  TELCO     EQ      208.20  194.0  217.80  194.0  213.1  213.25
# 3  2000-01-06  TELCO     EQ      213.25  215.0  229.90  215.0  222.0  222.10
# 4  2000-01-07  TELCO     EQ      222.10  224.0  239.90  223.1  239.9  239.90
#
#      VWAP   Volume      Turnover  Trades  Deliverable Volume  %Deliverble
# 0  214.28   676126  1.448775e+13     NaN                 NaN          NaN
# 1  209.50   679215  1.422962e+13     NaN                 NaN          NaN
# 2  210.33  1120951  2.357684e+13     NaN                 NaN          NaN
# 3  225.29  1968998  4.435932e+13     NaN                 NaN          NaN
# 4  236.32  2199431  5.197636e+13     NaN                 NaN          NaN

# %%
df.shape
# Out:
# (5306, 15)

# %%
df.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  5306.000000  5306.000000  5306.000000  5306.000000  5306.000000
# mean    409.432878   410.152752   417.122512   402.179438   409.451828
# std     272.483585   272.966475   277.018798   268.028297   272.516903
# min      58.800000    58.000000    60.700000    57.550000    58.750000
# 25%     174.600000   174.762500   178.825000   171.012500   174.725000
# 50%     377.250000   378.900000   384.750000   372.600000   377.525000
# 75%     523.150000   523.475000   530.800000   515.912500   523.487500
# max    1365.150000  1361.000000  1382.000000  1347.000000  1362.000000
#
#              Close         VWAP        Volume      Turnover        Trades  \
# count  5306.000000  5306.000000  5.306000e+03  5.306000e+03  2.456000e+03
# mean    409.450264   409.761357  1.046560e+07  2.790772e+14  1.284400e+05
# std     272.473264   272.491123  2.185034e+07  4.674351e+14  1.049546e+05
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                5306 non-null   object
#  1   Symbol              5306 non-null   object
#  2   Series              5306 non-null   object
#  3   Prev Close          5306 non-null   float64
#  4   Open                5306 non-null   float64
#  5   High                5306 non-null   float64
#  6   Low                 5306 non-null   float64
#  7   Last                5306 non-null   float64
#  8   Close               5306 non-null   float64
#  9   VWAP                5306 non-null   float64
#  10  Volume              5306 non-null   int64
#  11  Turnover            5306 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4792 non-null   float64
#  14  %Deliverble         4792 non-null   float64
# ...

# %% [markdown]
# # Data Pre-Processing

# %%
print(str('Any missing data or NaN in the dataset:'),df.isnull().values.any())
# Out:
# Any missing data or NaN in the dataset: True

# %%
df.isnull().sum()
# Out:
# Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2850
# Deliverable Volume     514
# %Deliverble            514
# dtype: int64

# %%
df1=df.dropna()

# %%
df1.isnull().sum()
# Out:
# Date                  0
# Symbol                0
# Series                0
# Prev Close            0
# Open                  0
# High                  0
# Low                   0
# Last                  0
# Close                 0
# VWAP                  0
# Volume                0
# Turnover              0
# Trades                0
# Deliverable Volume    0
# %Deliverble           0
# dtype: int64

# %%
df1.head()
# Out:
#             Date      Symbol Series  Prev Close    Open    High      Low  \
# 2850  2011-06-01  TATAMOTORS     EQ      1095.3  1096.0  1097.0  1075.60
# 2851  2011-06-02  TATAMOTORS     EQ      1079.9  1070.0  1070.0  1042.20
# 2852  2011-06-03  TATAMOTORS     EQ      1048.2  1048.0  1058.0  1014.25
# 2853  2011-06-06  TATAMOTORS     EQ      1023.8  1011.5  1031.8  1010.25
# 2854  2011-06-07  TATAMOTORS     EQ      1023.7  1017.0  1033.8  1015.65
#
#          Last   Close     VWAP   Volume      Turnover   Trades  \
# 2850  1077.25  1079.9  1083.36  2412309  2.613407e+14  76698.0
# 2851  1046.15  1048.2  1050.62  2604237  2.736056e+14  74650.0
# 2852  1024.60  1023.8  1031.52  3600090  3.713581e+14  94611.0
# 2853  1022.20  1023.7  1020.38  2076683  2.119014e+14  64914.0
# 2854  1028.00  1027.2  1027.38  2117760  2.175745e+14  56772.0
#
#       Deliverable Volume  %Deliverble
# 2850           1152083.0       0.4776
# 2851           1149341.0       0.4413
# ...

# %%
df2=df1.drop(columns=['Symbol'])

# %%
df3=df2.drop(columns=['Series'])

# %%
df4=df3.drop(columns=['Date'])

# %% [markdown]
# # Detecting and Removing Outliers

# %%
import seaborn as sns
sns.boxplot(x=df4["Prev Close"])
# Out:
# <AxesSubplot:xlabel='Prev Close'>

# %%
print(df4['Prev Close'].quantile(0.10))
print(df4['Prev Close'].quantile(0.90))
# Out:
# 150.47500000000002
# 518.025

# %%
df4["Prev Close"] = np.where(df4["Prev Close"] <150.47500000000002, 150.47500000000002,df4['Prev Close'])
df4["Prev Close"] = np.where(df4["Prev Close"] >518.025, 518.025,df4['Prev Close'])
print(df4['Prev Close'].skew())
# Out:
# 0.04064613435508522

# %%
sns.boxplot(x=df4["Prev Close"])
# Out:
# <AxesSubplot:xlabel='Prev Close'>

# %%
sns.boxplot(x=df4["Open"])
# Out:
# <AxesSubplot:xlabel='Open'>

# %%
print(df4['Open'].quantile(0.10))
print(df4['Open'].quantile(0.90))
# Out:
# 150.65
# 518.575

# %%
df4["Open"] = np.where(df4["Open"] <150.65, 150.65,df4['Open'])
df4["Open"] = np.where(df4["Open"] >518.575, 518.575,df4['Open'])
print(df4['Open'].skew())
# Out:
# 0.04080873247209708

# %%
sns.boxplot(x=df4["Open"])
# Out:
# <AxesSubplot:xlabel='Open'>

# %%
sns.boxplot(x=df4["High"])
# Out:
# <AxesSubplot:xlabel='High'>

# %%
print(df4['High'].quantile(0.10))
print(df4['High'].quantile(0.90))
# Out:
# 152.925
# 524.0

# %%
df4["High"] = np.where(df4["High"] <152.925, 152.925,df4['High'])
df4["High"] = np.where(df4["High"] >524.0, 524.0,df4['High'])
print(df4['High'].skew())
# Out:
# 0.033212752357455334

# %%
sns.boxplot(x=df4["High"])
# Out:
# <AxesSubplot:xlabel='High'>

# %%
sns.boxplot(x=df4["Low"])
# Out:
# <AxesSubplot:xlabel='Low'>

# %%
print(df4['Low'].quantile(0.10))
print(df4['Low'].quantile(0.90))
# Out:
# 146.825
# 511.075

# %%
df4["Low"] = np.where(df4["Low"] <146.825, 146.825,df4['Low'])
df4["Low"] = np.where(df4["Low"] >511.075, 511.075,df4['Low'])
print(df4['Low'].skew())
# Out:
# 0.04126996136740089

# %%
sns.boxplot(x=df4["Low"])
# Out:
# <AxesSubplot:xlabel='Low'>

# %%
sns.boxplot(x=df4["Last"])
# Out:
# <AxesSubplot:xlabel='Last'>

# %%
print(df4['Last'].quantile(0.10))
print(df4['Last'].quantile(0.90))
# Out:
# 150.52499999999998
# 518.0999999999999

# %%
df4["Last"] = np.where(df4["Last"] <150.52499999999998, 150.52499999999998,df4['Last'])
df4["Last"] = np.where(df4["Last"] >518.0999999999999, 518.0999999999999,df4['Last'])
print(df4['Last'].skew())
# Out:
# 0.04203071533561033

# %%
sns.boxplot(x=df4["Last"])
# Out:
# <AxesSubplot:xlabel='Last'>

# %%
sns.boxplot(x=df4["Close"])
# Out:
# <AxesSubplot:xlabel='Close'>

# %%
sns.boxplot(x=df4["VWAP"])
# Out:
# <AxesSubplot:xlabel='VWAP'>

# %%
print(df4['VWAP'].quantile(0.10))
print(df4['VWAP'].quantile(0.90))
# Out:
# 149.82999999999998
# 516.9549999999999

# %%
df4["VWAP"] = np.where(df4["VWAP"] <149.82999999999998, 149.82999999999998,df4['VWAP'])
df4["VWAP"] = np.where(df4["VWAP"] >516.9549999999999, 516.9549999999999,df4['VWAP'])
print(df4['VWAP'].skew())
# Out:
# 0.03447995969826689

# %%
sns.boxplot(x=df4["VWAP"])
# Out:
# <AxesSubplot:xlabel='VWAP'>

# %%
sns.boxplot(x=df4["Volume"])
# Out:
# <AxesSubplot:xlabel='Volume'>

# %%
print(df4['Volume'].quantile(0.10))
print(df4['Volume'].quantile(0.90))
# Out:
# 3938490.5
# 51699814.5

# %%
df4["Volume"] = np.where(df4["Volume"] <3938490.5, 3938490.5,df4['Volume'])
df4["Volume"] = np.where(df4["Volume"] >51699814.5, 51699814.5,df4['Volume'])
print(df4['Volume'].skew())
# Out:
# 1.458623835210814

# %%
sns.boxplot(x=df4["Volume"])
# Out:
# <AxesSubplot:xlabel='Volume'>

# %%
print(df4['Volume'].quantile(0.10))
print(df4['Volume'].quantile(0.90))
# Out:
# 3938530.75
# 51513983.75

# %%
df4["Volume"] = np.where(df4["Volume"] <3938530.75, 3938530.75,df4['Volume'])
df4["Volume"] = np.where(df4["Volume"] >51513983.75, 51513983.75,df4['Volume'])
print(df4['Volume'].skew())
# Out:
# 1.4550908021203144

# %%
sns.boxplot(x=df4["Volume"])
# Out:
# <AxesSubplot:xlabel='Volume'>

# %%
sns.boxplot(x=df4["Turnover"])
# Out:
# <AxesSubplot:xlabel='Turnover'>

# %%
print(df4['Turnover'].quantile(0.10))
print(df4['Turnover'].quantile(0.90))
# Out:
# 170934735217500.0
# 817923239390000.0

# %%
df4["Turnover"] = np.where(df4["Turnover"] <170934735217500.0, 170934735217500.0,df4['Turnover'])
df4["Turnover"] = np.where(df4["Turnover"] >817923239390000.0, 817923239390000.0,df4['Turnover'])
print(df4['Turnover'].skew())
# Out:
# 0

# %%
sns.boxplot(x=df4["Turnover"])
# Out:
# <AxesSubplot:xlabel='Turnover'>

# %%
sns.boxplot(x=df4["Trades"])
# Out:
# <AxesSubplot:xlabel='Trades'>

# %%
print(df4['Trades'].quantile(0.10))
print(df4['Trades'].quantile(0.90))
# Out:
# 57833.0
# 222880.5

# %%
df4["Trades"] = np.where(df4["Trades"] <57833.0, 57833.0,df4['Trades'])
df4["Trades"] = np.where(df4["Trades"] >222880.5, 222880.5,df4['Trades'])
print(df4['Trades'].skew())
# Out:
# 0.8976048787235795

# %%
sns.boxplot(x=df4["Trades"])
# Out:
# <AxesSubplot:xlabel='Trades'>

# %%
sns.boxplot(x=df4["Deliverable Volume"])
# Out:
# <AxesSubplot:xlabel='Deliverable Volume'>

# %%
print(df4['Deliverable Volume'].quantile(0.10))
print(df4['Deliverable Volume'].quantile(0.90))
# Out:
# 1680504.0
# 8669350.5

# %%
df4["Deliverable Volume"] = np.where(df4["Deliverable Volume"] <1680504.0, 1680504.0,df4['Deliverable Volume'])
df4["Deliverable Volume"] = np.where(df4["Deliverable Volume"] >8669350.5,8669350.5,df4['Deliverable Volume'])
print(df4['Deliverable Volume'].skew())
# Out:
# 0.7591254919715923

# %%
sns.boxplot(x=df4["Deliverable Volume"])
# Out:
# <AxesSubplot:xlabel='Deliverable Volume'>

# %%
sns.boxplot(x=df4["%Deliverble"])
# Out:
# <AxesSubplot:xlabel='%Deliverble'>

# %%
df4.head()
# Out:
#       Prev Close     Open   High      Low   Last  Close     VWAP      Volume  \
# 2850     518.025  518.575  524.0  511.075  518.1  517.5  516.955  3938530.75
# 2851     518.025  518.575  524.0  511.075  518.1  517.5  516.955  3938530.75
# 2852     518.025  518.575  524.0  511.075  518.1  517.5  516.955  3938530.75
# 2853     518.025  518.575  524.0  511.075  518.1  517.5  516.955  3938530.75
# 2854     518.025  518.575  524.0  511.075  518.1  517.5  516.955  3938530.75
#
#           Turnover   Trades  Deliverable Volume  %Deliverble
# 2850  1.709347e+14  76698.0           1680504.0       0.4776
# 2851  1.709347e+14  74650.0           1680504.0       0.4413
# 2852  1.709347e+14  94611.0           1680504.0       0.4090
# 2853  1.709347e+14  64914.0           1680504.0       0.2175
# 2854  1.709347e+14  57833.0           1680504.0       0.3803

# %%
df4.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  2456.000000  2456.000000  2456.000000  2456.000000  2456.000000
# mean    328.178950   328.534670   333.104296   323.219401   328.085485
# std     124.607913   124.797559   125.721578   123.552157   124.554093
# min     150.475000   150.650000   152.925000   146.825000   150.525000
# 25%     200.212500   199.800000   204.012500   197.050000   199.812500
# 50%     321.350000   322.950000   329.100000   316.125000   321.075000
# 75%     436.512500   436.562500   441.450000   431.200000   436.125000
# max     518.025000   518.575000   524.000000   511.075000   518.100000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count  2456.000000  2456.000000  2.456000e+03  2.456000e+03    2456.000000
# mean    328.035179   328.182972  1.596559e+07  1.709347e+14  115183.934853
# std     124.470873   124.544045  1.540171e+07  0.000000e+00   51241.389457
# ...

# %%
df4.shape
# Out:
# (2456, 12)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2456 entries, 2850 to 5305
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Prev Close          2456 non-null   float64
#  1   Open                2456 non-null   float64
#  2   High                2456 non-null   float64
#  3   Low                 2456 non-null   float64
#  4   Last                2456 non-null   float64
#  5   Close               2456 non-null   float64
#  6   VWAP                2456 non-null   float64
#  7   Volume              2456 non-null   float64
#  8   Turnover            2456 non-null   float64
#  9   Trades              2456 non-null   float64
#  10  Deliverable Volume  2456 non-null   float64
#  11  %Deliverble         2456 non-null   float64
# dtypes: float64(12)
# memory usage: 249.4 KB

# %% [markdown]
# # Train Test Split

# %%
X = df4.iloc[:, 0:11].values
print(X)
# Out:
# [[5.18025000e+02 5.18575000e+02 5.24000000e+02 ... 1.70934735e+14
#   7.66980000e+04 1.68050400e+06]
#  [5.18025000e+02 5.18575000e+02 5.24000000e+02 ... 1.70934735e+14
#   7.46500000e+04 1.68050400e+06]
#  [5.18025000e+02 5.18575000e+02 5.24000000e+02 ... 1.70934735e+14
#   9.46110000e+04 1.68050400e+06]
#  ...
#  [3.01500000e+02 3.03500000e+02 3.09500000e+02 ... 1.70934735e+14
#   2.22880500e+05 5.11656800e+06]
#  [3.05900000e+02 3.08900000e+02 3.10000000e+02 ... 1.70934735e+14
#   1.86996000e+05 4.19334600e+06]
#  [3.01900000e+02 2.98200000e+02 3.01300000e+02 ... 1.70934735e+14
#   2.22880500e+05 7.89898800e+06]]

# %%
Y = df4.iloc[:,11].values
print(Y)
# Out:
# [0.4776 0.4413 0.409  ... 0.1145 0.1144 0.2187]

# %%
from sklearn.model_selection import train_test_split
import numpy as np
X_train, X_test, y_train, y_test = train_test_split (X, Y, test_size=0.2, random_state=0)
print('Total no. of samples: Training and Testing dataset separately!')
print('X_train:', np.shape(X_train))
print('y_train:', np.shape(y_train))
print('X_test:', np.shape(X_test))
print('y_test:', np.shape(y_test))
# Out:
# Total no. of samples: Training and Testing dataset separately!
# X_train: (1964, 11)
# y_train: (1964,)
# X_test: (492, 11)
# y_test: (492,)

# %% [markdown]
# # Linear regression algorithm

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
lin_reg = LinearRegression()
lin_reg.fit(X_train,y_train)
accuracies=cross_val_score(estimator = lin_reg,X = X_train,y=y_train,cv=10)
y_pred = lin_reg.predict(X_test)
print('')
print('   Linear Regression   ')
print('Score : %.4f' % lin_reg.score(X_test,y_test))
print(accuracies)
print('Mean score: %0.3f' % accuracies.mean())
mse = mean_squared_error(y_test,y_pred)
rmse = mean_squared_error(y_test,y_pred)**0.5
r2 = r2_score(y_test,y_pred)
print('')
print(' MSE : %0.2f ' % mse)
print(' RMSE : %0.2f ' % rmse)
print(' R2 : %0.2f ' % r2)
# Out:
#    Linear Regression
# Score : 0.8344
# [0.84065144 0.84367613 0.81140099 0.8241436  0.75133099 0.820387
#  0.83428189 0.80248386 0.82011858 0.84652278]
# Mean score: 0.819
#
#  MSE : 0.00
#  RMSE : 0.07
#  R2 : 0.83
